# %% [markdown]
# # Budget exploration
# is there a relationship between budget and profit? profit margin?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
bommoviegross_df = pd.read_csv('data/bom.movie_gross.csv.gz')
imdbtitlebasics_df = pd.read_csv('data/imdb.title.basics.csv.gz')
imdbtitleratings_df = pd.read_csv('data/imdb.title.ratings.csv.gz')
budgets_df = pd.read_csv('data/tn.movie_budgets.csv.gz')

# %%
imdbtitlebasics_df['genrelist'] = imdbtitlebasics_df['genres'].map(lambda x: str(x).split(','))
imdbtitlebasics_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres                 genrelist
# 0        2013            175.0    Action,Crime,Drama    [Action, Crime, Drama]
# 1        2019            114.0       Biography,Drama        [Biography, Drama]
# 2        2018            122.0                 Drama                   [Drama]
# 3        2018              NaN          Comedy,Drama           [Comedy, Drama]
# 4        2017             80.0  Comedy,Drama,Fantasy  [Comedy, Drama, Fantasy]

# %%
bommoviegross_df.set_index('title', inplace = True)

# %%
budgets_lean = budgets_df.drop(columns = ['domestic_gross', 'worldwide_gross'])
budgets_lean.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget
# 0      $425,000,000
# 1      $410,600,000
# 2      $350,000,000
# 3      $330,600,000
# 4      $317,000,000

# %%
moviebudgets_df = bommoviegross_df.join(budgets_lean.set_index('movie'), how = 'inner')
moviebudgets_df.head()
# Out:
#                                           studio  domestic_gross  \
# 10 Cloverfield Lane                         Par.      72100000.0
# 12 Strong                                     WB      45800000.0
# 12 Years a Slave                            FoxS      56700000.0
# 127 Hours                                   FoxS      18300000.0
# 13 Hours: The Secret Soldiers of Benghazi   Par.      52900000.0
#
#                                           foreign_gross  year  id  \
# 10 Cloverfield Lane                            38100000  2016  54
# 12 Strong                                      21600000  2018  64
# 12 Years a Slave                              131100000  2013  18
# 127 Hours                                      42400000  2010   6
# 13 Hours: The Secret Soldiers of Benghazi      16600000  2016  30
#
#                                            release_date production_budget
# 10 Cloverfield Lane                        Mar 11, 2016        $5,000,000
# 12 Strong                                  Jan 19, 2018       $35,000,000
# 12 Years a Slave                           Oct 18, 2013       $20,000,000
# 127 Hours                                   Nov 5, 2010       $18,000,000
# 13 Hours: The Secret Soldiers of Benghazi  Jan 15, 2016       $50,000,000

# %%
def moneystr(str):
    no_dollar = str[1:]
    cleanstr = ''
    for i in range(len(no_dollar)):
        if no_dollar[i] != ',':
            cleanstr += no_dollar[i]
    return int(cleanstr)

# %%
moviebudgets_df['production_budget'] = moviebudgets_df['production_budget'].map(lambda x: moneystr(x))

# %%
moviebudgets_df.head()
# Out:
#                                           studio  domestic_gross  \
# 10 Cloverfield Lane                         Par.      72100000.0
# 12 Strong                                     WB      45800000.0
# 12 Years a Slave                            FoxS      56700000.0
# 127 Hours                                   FoxS      18300000.0
# 13 Hours: The Secret Soldiers of Benghazi   Par.      52900000.0
#
#                                           foreign_gross  year  id  \
# 10 Cloverfield Lane                            38100000  2016  54
# 12 Strong                                      21600000  2018  64
# 12 Years a Slave                              131100000  2013  18
# 127 Hours                                      42400000  2010   6
# 13 Hours: The Secret Soldiers of Benghazi      16600000  2016  30
#
#                                            release_date  production_budget
# 10 Cloverfield Lane                        Mar 11, 2016            5000000
# 12 Strong                                  Jan 19, 2018           35000000
# 12 Years a Slave                           Oct 18, 2013           20000000
# 127 Hours                                   Nov 5, 2010           18000000
# 13 Hours: The Secret Soldiers of Benghazi  Jan 15, 2016           50000000

# %%
bommoviegross_df.head()
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
#
#                                             foreign_gross  year
# title
# Toy Story 3                                     652000000  2010
# Alice in Wonderland (2010)                      691300000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# Shrek Forever After                             513900000  2010

# %%
moviebudgets_df.dropna(subset=['domestic_gross'], inplace=True)

# %%
moviebudgets_df.isna().sum()
# Out:
# studio                 1
# domestic_gross         0
# foreign_gross        161
# year                   0
# id                     0
# release_date           0
# production_budget      0
# dtype: int64

# %%
moviebudgets_df.studio.value_counts().head()
# Out:
# Uni.    117
# Fox     110
# WB      102
# Sony     74
# Par.     74
# Name: studio, dtype: int64

# %%
moviebudgets_df['domestic_profit'] = moviebudgets_df['domestic_gross'] - moviebudgets_df['production_budget']

# %%
moviebudgets_df.head()
# Out:
#                                           studio  domestic_gross  \
# 10 Cloverfield Lane                         Par.      72100000.0
# 12 Strong                                     WB      45800000.0
# 12 Years a Slave                            FoxS      56700000.0
# 127 Hours                                   FoxS      18300000.0
# 13 Hours: The Secret Soldiers of Benghazi   Par.      52900000.0
#
#                                           foreign_gross  year  id  \
# 10 Cloverfield Lane                            38100000  2016  54
# 12 Strong                                      21600000  2018  64
# 12 Years a Slave                              131100000  2013  18
# 127 Hours                                      42400000  2010   6
# 13 Hours: The Secret Soldiers of Benghazi      16600000  2016  30
#
#                                            release_date  production_budget  \
# 10 Cloverfield Lane                        Mar 11, 2016            5000000
# 12 Strong                                  Jan 19, 2018           35000000
# 12 Years a Slave                           Oct 18, 2013           20000000
# 127 Hours                                   Nov 5, 2010           18000000
# 13 Hours: The Secret Soldiers of Benghazi  Jan 15, 2016           50000000
#
#                                            domestic_profit
# 10 Cloverfield Lane                             67100000.0
# 12 Strong                                       10800000.0
# 12 Years a Slave                                36700000.0
# 127 Hours                                         300000.0
# 13 Hours: The Secret Soldiers of Benghazi        2900000.0

# %%
moviebudgets_df['profit_percentage'] = moviebudgets_df['domestic_profit']*100/moviebudgets_df['production_budget']

# %%
sns.lmplot(x='production_budget', y='profit_percentage', data=moviebudgets_df[moviebudgets_df['studio']=='LGF'])

# %%
moviebudgets_df.groupby('studio').sum().sort_values(by='profit_percentage', ascending=False).head()
# Out:
#          domestic_gross    year    id  production_budget  domestic_profit  \
# studio
# WB (NL)    3.417700e+09   74524  1795         2148600000     1.269100e+09
# Uni.       1.077074e+10  235628  6197         6597700000     4.173038e+09
# Par.       6.039100e+09  149021  3840         4770000000     1.269100e+09
# LGF        3.332373e+09  122839  3229         2069387650     1.262985e+09
# LG/S       1.542400e+09   62441  1805         1658350000    -1.159500e+08
#
#          profit_percentage
# studio
# WB (NL)       29425.550026
# Uni.          27934.003952
# Par.          19054.471323
# LGF            8917.628463
# LG/S           8224.058990

# %%
high_output_studios = moviebudgets_df[(moviebudgets_df['studio']=='Uni.')|
                                      (moviebudgets_df['studio']=='Fox')|
                                      (moviebudgets_df['studio']=='WB')]
high_output_studios.head()
# Out:
#                                    studio  domestic_gross foreign_gross  year  \
# 12 Strong                              WB      45800000.0      21600000  2018
# 2 Guns                               Uni.      75600000.0      56300000  2013
# 47 Ronin                             Uni.      38400000.0     113400000  2013
# A Good Day to Die Hard                Fox      67300000.0     237300000  2013
# A Very Harold & Kumar 3D Christmas     WB      35100000.0        326000  2011
#
#                                     id  release_date  production_budget  \
# 12 Strong                           64  Jan 19, 2018           35000000
# 2 Guns                              39   Aug 2, 2013           61000000
# 47 Ronin                            12  Dec 25, 2013          175000000
# A Good Day to Die Hard              34  Feb 14, 2013           92000000
# A Very Harold & Kumar 3D Christmas  53   Nov 4, 2011           20000000
#
#                                     domestic_profit  profit_percentage
# 12 Strong                                10800000.0          30.857143
# 2 Guns                                   14600000.0          23.934426
# 47 Ronin                               -136600000.0         -78.057143
# A Good Day to Die Hard                  -24700000.0         -26.847826
# A Very Harold & Kumar 3D Christmas       15100000.0          75.500000

# %%
sns.set_style('darkgrid')
sns.lmplot(x='production_budget', y='profit_percentage',
           hue='studio',palette='Blues', height=10, data=high_output_studios).set(title = 'Percent Profit vs. Production Budget');
